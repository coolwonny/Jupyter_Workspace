# %% [markdown]
# # Bank of America Stock Data

# %% [markdown]
# ## 1. Import Libraries and Dependencies

# %%
# Import the module pandas as pd
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## 2. Set File Path for CSV using Pathlib

# %%
# Set the path of the BAC stock data file to be loaded from the Data folder.
csvpath = Path('../Resources/BAC.csv')

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Define a variable "BAC_df" and store the BAC.csv into Pandas DataFrame using the BAC_path
BAC_df = pd.read_csv(csvpath)
BAC_df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-01-03  22.600000  22.680000  22.200001  22.530001  22.006727
# 1    2017-01-04  22.719999  22.959999  22.600000  22.950001  22.416971
# 2    2017-01-05  22.820000  22.930000  22.350000  22.680000  22.153240
# 3    2017-01-06  22.780001  22.850000  22.559999  22.680000  22.153240
# 4    2017-01-09  22.510000  22.709999  22.400000  22.549999  22.026258
# ..          ...        ...        ...        ...        ...        ...
# 246  2017-12-22  29.980000  30.030001  29.620001  29.879999  29.647165
# 247  2017-12-26  29.740000  29.940001  29.580000  29.780001  29.547947
# 248  2017-12-27  29.660000  29.730000  29.600000  29.730000  29.498335
# 249  2017-12-28  29.730000  29.820000  29.660000  29.799999  29.567789
# 250  2017-12-29  29.850000  29.879999  29.520000  29.520000  29.289972
#
#        Volume
# 0    99298100
# 1    76875100
# 2    86826400
# 3    66281500
# 4    75744700
# ..        ...
# 246  54203000
# 247  42371200
# 248  35111800
# 249  37914900
# 250  40672000
#
# [251 rows x 7 columns]

# %% [markdown]
# ## 4. Count Number of Rows in the DataFrame

# %%
# Use the `count` function to count the number of non-null rows for each column
BAC_df.count()
# Out:
# Date         251
# Open         251
# High         251
# Low          251
# Close        251
# Adj Close    251
# Volume       251
# dtype: int64

# %% [markdown]
# ## 5. Calculate the Min and Max Dates

# %%
# Define two variables labeled "earliest_date" and "latest_date"
# Set them equal to the earliest/lastest of Date in bac
earliest_date = BAC_df.iloc[0, 0]
lastest_date = BAC_df.iloc[-1, 0]
# print the earliest and latest dates
print(f'earliest date: {earliest_date}')
print(f'lastest date: {lastest_date}')
# Out:
# earliest date: 2017-01-03
# lastest date: 2017-12-29

# %% [markdown]
# ## 6. Set Date as Index

# %%
# Use the `set_index` function to set the `Date` as the index to the DataFrame
BAC_df.set_index(BAC_df['Date'], inplace=True)
BAC_df
# Out:
#                   Date       Open       High        Low      Close  Adj Close  \
# Date
# 2017-01-03  2017-01-03  22.600000  22.680000  22.200001  22.530001  22.006727
# 2017-01-04  2017-01-04  22.719999  22.959999  22.600000  22.950001  22.416971
# 2017-01-05  2017-01-05  22.820000  22.930000  22.350000  22.680000  22.153240
# 2017-01-06  2017-01-06  22.780001  22.850000  22.559999  22.680000  22.153240
# 2017-01-09  2017-01-09  22.510000  22.709999  22.400000  22.549999  22.026258
# ...                ...        ...        ...        ...        ...        ...
# 2017-12-22  2017-12-22  29.980000  30.030001  29.620001  29.879999  29.647165
# 2017-12-26  2017-12-26  29.740000  29.940001  29.580000  29.780001  29.547947
# 2017-12-27  2017-12-27  29.660000  29.730000  29.600000  29.730000  29.498335
# 2017-12-28  2017-12-28  29.730000  29.820000  29.660000  29.799999  29.567789
# 2017-12-29  2017-12-29  29.850000  29.879999  29.520000  29.520000  29.289972
#
#               Volume
# Date
# 2017-01-03  99298100
# 2017-01-04  76875100
# 2017-01-05  86826400
# 2017-01-06  66281500
# 2017-01-09  75744700
# ...              ...
# 2017-12-22  54203000
# 2017-12-26  42371200
# 2017-12-27  35111800
# 2017-12-28  37914900
# 2017-12-29  40672000
#
# [251 rows x 7 columns]

# %% [markdown]
# ## 7. Filter DataFrame Between 2017-01-03 to 2017-06-03

# %%
# After setting the `Date` as the index, loc can be used to specify a range of dates
df = BAC_df.loc['2017-01-03':'2017-06-03']
df
# Out:
#                   Date       Open       High        Low      Close  Adj Close  \
# Date
# 2017-01-03  2017-01-03  22.600000  22.680000  22.200001  22.530001  22.006727
# 2017-01-04  2017-01-04  22.719999  22.959999  22.600000  22.950001  22.416971
# 2017-01-05  2017-01-05  22.820000  22.930000  22.350000  22.680000  22.153240
# 2017-01-06  2017-01-06  22.780001  22.850000  22.559999  22.680000  22.153240
# 2017-01-09  2017-01-09  22.510000  22.709999  22.400000  22.549999  22.026258
# ...                ...        ...        ...        ...        ...        ...
# 2017-05-26  2017-05-26  23.230000  23.420000  23.170000  23.240000  22.769428
# 2017-05-30  2017-05-30  23.129999  23.209999  22.879999  22.910000  22.446112
# 2017-05-31  2017-05-31  22.780001  22.799999  22.090000  22.410000  22.028347
# 2017-06-01  2017-06-01  22.480000  22.639999  22.299999  22.629999  22.244600
# 2017-06-02  2017-06-02  22.270000  22.590000  22.160000  22.450001  22.067667
#
#                Volume
# Date
# 2017-01-03   99298100
# 2017-01-04   76875100
# 2017-01-05   86826400
# 2017-01-06   66281500
# 2017-01-09   75744700
# ...               ...
# 2017-05-26   50399500
# 2017-05-30   61307900
# 2017-05-31  138636300
# 2017-06-01   69725100
# 2017-06-02   79722300
#
# [105 rows x 7 columns]

# %% [markdown]
# ## 8. Drop Extra Columns

# %%
# Drop the extra columns (Close is dropped because there is an Adj Close column)
df = df.drop(columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
df
# Out:
#             Adj Close
# Date
# 2017-01-03  22.006727
# 2017-01-04  22.416971
# 2017-01-05  22.153240
# 2017-01-06  22.153240
# 2017-01-09  22.026258
# ...               ...
# 2017-05-26  22.769428
# 2017-05-30  22.446112
# 2017-05-31  22.028347
# 2017-06-01  22.244600
# 2017-06-02  22.067667
#
# [105 rows x 1 columns]

# %% [markdown]
# ## 9. Calculate Daily Returns for Six Months of BAC Closing Prices

# %%
# Use the `pct_change` function to calculate the daily returns over the date range of closing BAC prices
daily_returns = df.pct_change()

# %% [markdown]
# ## 10. Plot the Daily Returns for 6 Months of BAC Stock

# %%
# Use the `plot` function to visualize the daily returns over the 6 month period for BAC
daily_returns.plot()
