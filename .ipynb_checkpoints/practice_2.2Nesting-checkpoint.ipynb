# %%
# # -*- coding: utf-8 -*-
# """
# Instructor Demo: Nesting.

# This script showcases how to traverse dictionary of dicts.
# """

# # Dictionary of Dicts
# stocks_nested_dict = {
#     "APPL": {
#         "name": "Apple",
#         "exchange": "NASDAQ",
#         "market_cap": 937.7
#     },
#     "MU": {
#         "name": "Micron Technology",
#         "exchange": "NASDAQ",
#         "market_cap": 48.03
#     },
#     "AMD": {
#         "name": "Advanced Micro Devices",
#         "exchange": "NASDAQ",
#         "market_cap": 29.94
#     },
#     "TWTR": {
#         "name": "Twitter",
#         "exchange": "NASDAQ",
#         "market_cap": 26.42
#     }
# }

# # Retrieve Twitter entry
# twitter_entry = stocks_nested_dict["TWTR"]
# print(twitter_entry)

# # Retrieve TWTR name, exchange, and market_cap
# twitter_name = stMocks_nested_dict["TWTR"]["name"]
# print(twitteMr_namMr_exchange)
# twitter_market_cap = stocks_nested_dict["TWTR"]["market_cap"]
# print(twitter_market_cap)

# # Print results to screen
# print(f"Name of TWTR ticker is {twitter_name}. TWTR is available on {twitter_exchange}, and it currently has a market capitalization of {twitter_market_cap}.")

# %%
# # -*- coding: utf-8 -*-
# """
# Instructor Demo: Nesting.

# This script showcases how to traverse dictionary of lists.
# """

# # Dict
# stocks_dict = {
#     "APPL": 101.32,
#     "MU": 43.4,
#     "AMD": 23.12,
#     "TWTR": 25
# }

# # Dictionary of Lists
# stocks_nested_list = {
#     "APPL": ["Apple", 101.32, "NASDAQ", 937.7],
#     "MU": ["Micron Technology", 32.12, "NASDAQ", 48.03],
#     "AMD": ["Advanced Micro Devices", 23.12, "NASDAQ", 29.94],
#     "TWTR": ["Twitter", 34.40, "NASDAQ", 26.42]
# }
# print(stocks_nested_list)

# # Retrieve entry for APPL
# appl_entry = stocks_nested_list["APPL"]

# # Retrieve name, stock_price, and exchange for APPL entry
# appl_name = stocks_nested_list["APPL"][0]
# appl_stock_price = stocks_nested_list["APPL"][1]
# appl_exchange = stocks_nested_list["APPL"][2]

# # Print results to screen
# print(f"APPL ticker stands for {appl_name}. APPL stock price is currently {appl_stock_price}, and it is available on {appl_exchange}.")

# %%
# # -*- coding: utf-8 -*-
# """
# Instructor Demo: Nesting.

# This script showcases how to traverse nested lists of lists.
# """

# # List
# ceo_list = ["Warren", "Jack", "Harry"]

# # List of Lists
# ceo_nested_list = [
#     ["Warren Buffet", 88, "CEO of Berkshire Hathaway"],
#     ["Jeff Bezos", 55, "CEO of Amazon"],
#     ["Harry Markowitz", 91, "Professor of Finance"]
# ]

# # Retrieve first entry of ceo_nested_list
# first_entry = ceo_nested_list[0]
# print(first_entry)

# # Retrieve name of first entry
# first_entry_name = ceo_nested_list[0][0]
# print(first_entry_name)

# # Retrieve age of first entry
# first_entry_age = ceo_nested_list[0][1]

# # Retrieve occupation of first entry
# first_entry_occupation = ceo_nested_list[0][2]

# # Print results to screen
# print("The first entry in employees_nested_list is:", first_entry)
# print(f"{first_entry_name} is {first_entry_age} years old, serving as {first_entry_occupation}.")

# %%
# # -*- coding: utf-8 -*-
# """
# Instructor Demo: Nesting.

# This script showcases how to traverse list of dicts.
# """

# # List of Dicts
# ceo_nested_dict = [
#     {
#         "name": "Warren Buffet",
#         "age": 88,
#         "occupation": "CEO of Berkshire Hathaway"
#     },
#     {
#         "name": "Jeff Bezos",
#         "age": 55,
#         "occupation": "CEO of Amazon"
#     },
#     {
#         "name": "Harry Markowitz",
#         "age": 91,
#         "occupation": "Professor of Finance"
#     }
# ]

# # Retrieve second entry
# second_entry = ceo_nested_dict[1]
# print(second_entry)

# # Retrieve name, age, and occupation of the second dict entry
# second_entry_name = ceo_nested_dict[1]["name"]
# second_entry_age = ceo_nested_dict[1]["age"]
# second_entry_occupation = ceo_nested_dict[1]["occupation"]

# # Print results to the screen
# print(f"The second entry in ceo_nested_dict is {second_entry_name}, a {second_entry_age} year old {second_entry_occupation}.")

# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Weekly Gains.

This script showcases how to use nested list/dict objects to
calculate weekly gains of stock tickers.
"""

# Dictionary of List of Lists
# Key: Stock Ticker | Value: List of Records
# Record: Date, Open, High, Low, Close
# historical_stock_data = {
#     "AAPL": [
#         ["04-17-2019", 199.54, 203.38, 198.61, 203.13],
#         ["04-18-2019", 199.46, 201.37, 198.56, 199.25],
#         ["04-19-2019", 198.58, 199.85, 198.01, 199.23],
#         ["04-20-2019", 199.20, 200.14, 196.21, 198.87],

#     ],
#     "MU": [
#         ["04-17-2019", 43.20, 43.53, 42.79, 43.40],
#         ["04-18-2019", 43.36, 44.05, 42.76, 43.15],
#         ["04-19-2019", 42.26, 42.93, 42.08, 42.76],
#         ["04-20-2019", 42.17, 42.23, 41.20, 41.82],

#     ],
#     "AMD": [
#         ["04-17-2019", 27.60, 27.88, 27.34, 27.68],
#         ["04-18-2019", 28.21, 28.27, 27.22, 27.49],
#         ["04-19-2019", 27.72, 28.18, 27.49, 27.93],
#         ["04-20-2019", 27.80, 27.84, 26.96, 27.33],

#     ],
#     "TWTR": [
#         ["04-17-2019", 34.67, 34.86, 34.32, 34.40],
#         ["04-18-2019", 34.73, 34.90, 34.20, 34.48],
#         ["04-19-2019", 34.84, 34.99, 34.23, 34.46],
#         ["04-20-2019", 34.38, 35.03, 34.34, 34.71],

#     ]
# }

# # Dictionary of Dictionary
# # Key: Stock Ticker | Value: Dictionary
# new_records = {
#     "AAPL": {
#         "date": "04-21-2019",
#         "open": 200.85,
#         "high": 201.00,
#         "low": 198.44,
#         "close": 198.95
#     },
#     "MU": {
#         "date": "04-21-2019",
#         "open": 42.85,
#         "high": 43.20,
#         "low": 41.81,
#         "close": 42.01
#     },
#     "AMD": {
#         "date": "04-21-2019",
#         "open": 28.21,
#         "high": 28.38,
#         "low": 27.66,
#         "close": 27.85
#     },
#     "TWTR": {
#         "date": "04-21-2019",
#         "open": 34.67,
#         "high": 34.83,
#         "low": 34.11,
#         "close": 34.37
#     }
# }

# @TODO: Set each ticker's new record: date, open, high, low, close
# aapl_date = new_records["AAPL"]["date"]
# aapl_open = new_records["AAPL"]["open"]
# aapl_high = new_records["AAPL"]["high"]
# aapl_low = new_records["AAPL"]["low"]
# aapl_close = new_records["AAPL"]["close"]


# @TODO: Choice 1: Add a new round of entries to the 'historical_stock_data' dictionary
# historical_stock_data["AAPL"].append([aapl_date, aapl_open, aapl_high, aapl_low, aapl_close])
                                     
# print(historical_stock_data["AAPL"])

# @TODO: Choice 2: Add a new round of entries via for loop to the 'historical_stock_data' dictionary
# aapl_records = []
# mu_records = []
# amd_records = []
# twtr_records = []

# for x, y in new_records.items():
#     if x == "AAPL":
#        date_value = y["date"]
#        open_value = y["open"]
#        high_value = y["high"]
#        low_value = y["low"]
#        close_value = y["close"]
#        aapl_records = [date_value, open_value, high_value, low_value, close_value]
#     elif x == "MU":
#        date_value = y["date"]
#        open_value = y["open"]
#        high_value = y["high"]
#        low_value = y["low"]
#        close_value = y["close"]
#        mu_records = [date_value, open_value, high_value, low_value, close_value]
#     elif x == "AMD":
#        date_value = y["date"]
#        open_value = y["open"]
#        high_value = y["high"]
#        low_value = y["low"]
#        close_value = y["close"]
#        amd_records = [date_value, open_value, high_value, low_value, close_value]
#     elif x == "TWTR":
#        date_value = y["date"]
#        open_value = y["open"]
#        high_value = y["high"]
#        low_value = y["low"]
#        close_value = y["close"]
#        twtr_records = [date_value, open_value, high_value, low_value, close_value]

# ticker = [aapl_records, mu_records, amd_records, twtr_records]

# historical_stock_data["AAPL"].append(ticker[0])
# # historical_stock_data["MU"].append(ticker[1])
# # historical_stock_data["AMD"].append(ticker[2])
# # historical_stock_data["TWTR"].append(ticker[3])

# print(historical_stock_data["AAPL"])
   

# @TODO: Choice 2: Add a new round of entries via for loop to the 'historical_stock_data' dictionary
# for x, y in new_records.items():
#     new_data = [y["date"], y["open"], y["high"], y["low"], y["close"]]
#     historical_stock_data[x].append(new_data)
# print(historical_stock_data)

# @TODO: Print out the modified 'historical_stock_data' dictionary

# %%
# Challenge
historical_stock_data = {
    "AAPL": [
        ["04-17-2019", 199.54, 203.38, 198.61, 203.13],
        ["04-18-2019", 199.46, 201.37, 198.56, 199.25],
        ["04-19-2019", 198.58, 199.85, 198.01, 199.23],
        ["04-20-2019", 199.20, 200.14, 196.21, 198.87],

    ],
    "MU": [
        ["04-17-2019", 43.20, 43.53, 42.79, 43.40],
        ["04-18-2019", 43.36, 44.05, 42.76, 43.15],
        ["04-19-2019", 42.26, 42.93, 42.08, 42.76],
        ["04-20-2019", 42.17, 42.23, 41.20, 41.82],

    ],
    "AMD": [
        ["04-17-2019", 27.60, 27.88, 27.34, 27.68],
        ["04-18-2019", 28.21, 28.27, 27.22, 27.49],
        ["04-19-2019", 27.72, 28.18, 27.49, 27.93],
        ["04-20-2019", 27.80, 27.84, 26.96, 27.33],

    ],
    "TWTR": [
        ["04-17-2019", 34.67, 34.86, 34.32, 34.40],
        ["04-18-2019", 34.73, 34.90, 34.20, 34.48],
        ["04-19-2019", 34.84, 34.99, 34.23, 34.46],
        ["04-20-2019", 34.38, 35.03, 34.34, 34.71],

    ]
}

# Dictionary of Dictionary
# Key: Stock Ticker | Value: Dictionary
new_records = {
    "AAPL": {
        "date": "04-21-2019",
        "open": 200.85,
        "high": 201.00,
        "low": 198.44,
        "close": 198.95
    },
    "MU": {
        "date": "04-21-2019",
        "open": 42.85,
        "high": 43.20,
        "low": 41.81,
        "close": 42.01
    },
    "AMD": {
        "date": "04-21-2019",
        "open": 28.21,
        "high": 28.38,
        "low": 27.66,
        "close": 27.85
    },
    "TWTR": {
        "date": "04-21-2019",
        "open": 34.67,
        "high": 34.83,
        "low": 34.11,
        "close": 34.37
    }
}
for x, y in new_records.items():
    new = [y["date"], y["open"], y["high"], y["low"], y["close"]]
    historical_stock_data[x].append(new)

# Calculate the weekly gains for each stock ticker and assign to a results dictionary for each stock ticker.
# "TWTR": [
#         ["04-17-2019", 34.67, 34.86, 34.32, 34.40],
#         ["04-18-2019", 34.73, 34.90, 34.20, 34.48],
#         ["04-19-2019", 34.84, 34.99, 34.23, 34.46],
#         ["04-20-2019", 34.38, 35.03, 34.34, 34.71],
# Loop through every key-value pair in the historical_stock_data dictionary.
result = {}
for a, b in historical_stock_data.items():
    beginning_weekly_close = b[0][1]
    ending_weekly_close = b[4][4]
    ticker_weekly_close = round((ending_weekly_close - beginning_weekly_close) / beginning_weekly_close * 100, 2) 
    result[a] = ticker_weekly_close
print(result)
# Out:
# {'AAPL': -0.3, 'MU': -2.75, 'AMD': 0.91, 'TWTR': -0.87}
