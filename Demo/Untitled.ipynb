# %%
customers = [
    { "first_name": "Tom", "last_name": "Bell", "revenue": 0 },
    { "first_name": "Maggie", "last_name": "Johnson", "revenue": 1032 },
    { "first_name": "John", "last_name": "Spectre", "revenue": 2543 },
    { "first_name": "Susy", "last_name": "Simmons", "revenue": 5322 }
]

Platinum = 3001+
Gold = 2001-3000
Silver = 1001-2000
Bronze = 0-1000

def create_greeting(first_name, last_name, revenue):
    if revenue > 3000:
        greeting = f"Welcome {first_name} {last_name}, Platinum customer! Your revenue is {revenue}."
    elif (revenue <= 3000) and (revenue > 2000):
        greeting = f"Welcome {first_name} {last_name}, Gold customer! Your revenue is {revenue}."
    elif (revenue <= 2000) and (revenue > 1000):
        greeting = f"Welcome {first_name} {last_name}, Silver customer! Your revenue is {revenue}."
    elif (revenue <= 1000) and (revenue >= 0):
        greeting = f"Welcome {first_name} {last_name}, Bronze customer! Your revenue is {revenue}."
  
    return greeting

for x in customers:
    print(create_greeting(customer['first_name'], customer['last_name'], customer['revenue']))
# Out:
#   File "<ipython-input-1-2501b058c323>", line 8
#     Platinum = 3001+
#                     ^
# SyntaxError: invalid syntax

# %%
"""
Zero-Coupon Bond Valuation.

This script will calculate the present value of zero-coupon bonds, compare the present value to the price of the bond, and determine the corresponding action (buy, not buy, neutral).
"""


# @TODO: Create a function to calculate present value
def calculate_present_value(future_value, discount_rate, compounding_periods, years):
     present_value = future_value / ((1 + discount_rate / compounding_periods))**(compounding_periods / years)
     present_value_final = round(present_value, 2)
     return present_value_final


# Intialize the zero-coupon bond parameters, assume compounding period is equal to 1
price = 700
future_value = 1000
discount_rate = .1
compounding_periods = 1
years = 5

print(calculate_present_value(future_value, discount_rate, compounding_periods, years))
# @TODO: Call the calculate_present_value() function and assign to a variables


# @TODO: Determine if the bond is worth it
# Out:
# 981.12

# %%
"""Student Activity: Financial Analysis using NPV.

This script will choose the optimal project scenario to
undertake based on max NPV values.
"""

# @TODO: Import the NumPy library
import numpy_financial as npf

# Discount Rate
discount_rate = .1

# Initial Investment, Cash Flow 1, Cash Flow 2, Cash Flow 3, Cash Flow 4
cash_flows_conservative = [-1000, 400, 400, 400, 400]
cash_flows_neutral = [-1500, 600, 600, 600, 600]
cash_flows_aggressive = [-2250, 800, 800, 800, 800]

# @TODO: Initialize dictionary to hold NPV return values
npv_dict = {}

# @TODO: Calculate the NPV for each scenario
npv_conservative = round(npf.npv(discount_rate, cash_flows_conservative), 2)
npv_neutral = round(npf.npv(discount_rate, cash_flows_neutral), 2)
npv_aggressive = round(npf.npv(discount_rate, cash_flows_aggressive), 2)

# @TODO: Initialize variables
npv_dict["conservative"] = npv_conservative
npv_dict["neutral"] = npv_neutral
npv_dict["aggressive"] = npv_aggressive

# @TODO: Iterate over npv_dict to find the max key-value pair
# minimum = 0
# maximum = 0
# minimum_key =""
# maximum_key = ""
# for x, y in npv_dict.items():
#     if y < minimum:
#         minimum = y
#         minimum_key = x
#     elif y > maximum:
#         maximum = y
#         maximum_key = x
maximum = max(npv_dict)
maximum_value = npv_dict[maximum]
print(npv_dict)
print(f"The scenario with the highest NPV value is {maximum}, with NPV of {maximum_value}" )

# @TODO: Print out the optimal project scenario with the highest NPV value
# Out:
# {'conservative': 267.95, 'neutral': 401.92, 'aggressive': 285.89}
# The scenario with the highest NPV value is neutral, with NPV of 401.92

# %%
from pathlib import Path
Path.cwd()
filepath = Path("..\Resources\input.txt")

# %%
with open(filepath, "r") as file:
    text =  iter(file)
    print(next(text))
    
    line_num = 1
    for line in file:
        print(f"line {line_num}: {line}")
        line_num += 1
# Out:
# First Name,Last Name,SSN,Salary
#
# line 1: Tina,Fleming,619-16-7988,75000
#
# line 2: Erica,Shah,164-51-7615,40000
#
# line 3: Paula,Ortiz,051-83-3290,120000
#
# line 4: James,Hendricks,776-83-2884,90000
#
# line 5: Lauren,King,197-94-2398,60000
#
# line 6: David,Cowan,252-92-1832,35000
#
# line 7: Andrew,Burton,296-23-6842,150000
#
# line 8: Julian,Baker,337-40-7543,75000
#
# line 9: Scott,Castro,399-46-5595,50000
#
# line 10: Billy,Rodriguez,014-18-2503,65000
#
# line 11: Darrell,Leblanc,005-82-7918,40000
#
# line 12: David,Hammond,561-17-6312,90000

# %%
"""Instructor Demo: File IO.

This script will use the Pathlib library to set the file path
and Python's built-in open() function to read in a text file. Then
write the contents to an output file.
"""

# Import from the pathlib library, the main class Path
from pathlib import Path

# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")


# Set the input file path irregardless of OS
filepath = Path("../Resources/input.txt")

# Open the file in "read" mode ('r') and store the
# contents in the variable "text"
with open(filepath, 'r') as file:
    # Store all of the text from the file inside a variable called "text"
    # and print the contexts of the text file
    text = file.read()
    print(text)
    
    line_num = 1
    for line in file:
        print(f"line {line_num}: {line}")
        line_num += 1
# Out:
# Current Working Directory: C:\Users\Sungwon Kim\fintech\Jupyter_Workspace\Demo
# List of Best Actors:
# Nicolas Cage
# Betty White
# Gary Busey

# %%
"""Student Do: E-Commerce Traffic.

This script will parse through a text file and sum the total
number of customers and the count of days in the text file to
calculate the daily average of customer traffic for an e-commerce
business.
"""

# @TODO: From the pathlib library, import the main class Path
from pathlib import Path

# @TODO: Check the current directory where the Python program is executing from
print(f"working directory: {Path.cwd()}")

# @TODO: Set the path using Pathlib
filepath = Path("../Resources/customer_traffic.txt")
print(filepath)

# Initialize variables
customer_total = 0
day_count = 0

# @TODO: Open the file in "read" mode ('r') and store the contents in the variable 'file'
with open(filepath, 'r') as file:
 
        
    # @TODO: Parse the file line by line
     for line in file:

        # @TODO: Convert the number in the text file from string to int (allows for numerical calculations)
         num =  int(line)

        # @TODO: Sum the total and count of the numbers in the text file
         customer_total += num
         day_count += 1


# @TODO: Print out customer_total and day_count
print(f"customer_total is {customer_total} and day count is {day_count}")

# @TODO: Calculate the average

average = customer_total / day_count

# @TODO: Set output file name
output_path = Path("output.txt")

# @TODO: Open the output path as a file object
with open(output_path, "w") as file:
    file.write("The average is {average}")

    # @TODO: Write daily_average to the output file, convert to string
# Out:
# working directory: C:\Users\Sungwon Kim\fintech\Jupyter_Workspace\Demo
# ..\Resources\customer_traffic.txt
# customer_total is 4945 and day count is 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-1d011f30e346> in <module>
#      51
#      52     # @TODO: Write daily_average to the output file, convert to string
# ---> 53 print(file())
#
# TypeError: '_io.TextIOWrapper' object is not callable

# %%
import csv
filepath = Path("../Resources/accounting.csv")
salaries = []
with open(filepath, 'r') as file:
    csvreader = csv.reader(file)
    header =  next(csvreader)
    for line in csvreader:
        salaries.append(int(line[3]))
min_salaries = min(salaries)
max_salaries = max(salaries)
ave_salaries = sum(salaries) / len(salaries)

header_agg = ['min', 'max', 'ave']
output = [min_salaries, max_salaries, ave_salaries]

output_path = Path("output.csv")
with open(output_path, 'w') as file:
    csvwriter = csv.writer()
# Out:
# [75000,
#  40000,
#  120000,
#  90000,
#  60000,
#  35000,
#  150000,
#  75000,
#  50000,
#  65000,
#  40000,
#  90000]

# %%
"""Instructor Demo: CSV Reader.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, iterate over each
row of the file to capture employee salaries, calculate min,
max, avg metrics of employee salaries, and write the metrics
to a csv file.
"""
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('../Resources/accounting.csv')

# Initialize variable to hold salaries
salaries = []

# Initialize line_num variable
line_num = 0

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:

    # Print the datatype of the file object
    print(type(csvfile))

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')
    # Print the datatype of the csvreader
    print(type(csvreader))

    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate line_num by 1
    header = next(csvreader)
    line_num += 1
    # Print the header
    print(f"{header} <---- HEADER")
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
        # Set salary variable equal to the value in the 4th column of each row
        salary = int(row[3])
        # Append the row salary value to the list of salaries
        salaries.append(salary)

# %%
"""Student Do: Sales Analysis.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, and iterate over each
row of the file to calculate customer sales averages.
"""

# @TODO: Import the pathlib and csv library
from pathlib import Path
import csv


# @TODO: Set the file path
filepath = Path("../Resoruces/sales.csv")

# Initialize list of records
records = []

# @TODO: Open the csv file as an object
with open(filepath, 'r') as file:
    

    # @TODO:
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
      csvreader = csv.
    # @TODO: Read the header row

    # @TODO: Print the header


    # @TODO: Append the column 'Average' to the header

    # @TODO: Append the header to the list of records


    # @TODO: Read each row of data after the header

        # @TODO: Print the row

        # @TODO:
        # Set the 'name', 'count', 'revenue' variables for better
        # readability, convert strings to ints for numerical calculations




        # @TODO: Calculate the average (round to the nearest 2 decimal places)


        # @TODO: Append the average to the row

        # @TODO: Append the row to the list of records


# @TODO: Set the path for the output.csv

# @TODO:
# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','


    # @TODO:
    # Loop through the list of records and write every record to the
    # output csv file
