# %% [markdown]
# # Spring Cleaning!

# %% [markdown]
# Harold's stock data is a mess! Help him clean up his data before the auditors arrive!

# %%
# Import Libraries
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Load CSV data into Pandas using `read_csv`

# %%
csvpath = Path('../../Resources/stock_data.csv')
df = pd.read_csv(csvpath)
df.head()
# Out:
#   symbol                 name                  sector    price  \
# 0    MMM           3M Company             Industrials  $222.89
# 1    AOS      A.O. Smith Corp             Industrials      NaN
# 2    ABT  Abbott Laboratories             Health Care    56.27
# 3   ABBV          AbbVie Inc.             Health Care   108.48
# 4   ATVI  Activision Blizzard  Information Technology    65.83
#
#    price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0               24.31        2.332862              $7.92      259.770
# 1                 NaN             NaN                NaN          NaN
# 2               22.51        1.908982               0.26       64.600
# 3               19.41        2.499560               3.29      125.860
# 4                 NaN        0.431903               1.28       74.945
#
#    52_week_high    market_cap        ebitda  price_per_sales  price_per_book  \
# 0        175.49  1.387211e+11  9.048000e+09         4.390271           11.34
# 1           NaN           NaN           NaN              NaN             NaN
# 2         42.28  1.021210e+11  5.744000e+09         3.740480            3.19
# 3         60.05  1.813863e+11  1.031000e+10         6.291571           26.14
# 4         38.93  5.251867e+10  2.704000e+09        10.595120            5.16
#
#                                          sec_filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1                                                NaN
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify the number of rows and columns (shape) in the DataFrame.

# %%
df.shape
# Out:
# (504, 14)

# %% [markdown]
# ### Generate a sample of the data to visually ensure data has been loaded in correctly.

# %%
df.sample(10)
# Out:
#     symbol                      name                      sector   price  \
# 453    TSN               Tyson Foods            Consumer Staples   73.92
# 425    SYF       Synchrony Financial                  Financials   34.98
# 192     FE          FirstEnergy Corp                   Utilities   30.64
# 333    NKE                      Nike      Consumer Discretionary   62.49
# 401   SPGI          S&P Global, Inc.                  Financials  173.31
# 57       T                  AT&T Inc  Telecommunication Services   35.57
# 227   HSIC              Henry Schein                 Health Care   70.85
# 244   INCY                    Incyte                 Health Care   83.92
# 199      F                Ford Motor      Consumer Discretionary   10.43
# 181   EXPD  Expeditors International                 Industrials   60.36
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 453               13.92        1.635323               4.79       84.650
# 425               13.35        1.600000               2.41       40.590
# 192               11.18        4.673807             -14.49       35.220
# 333               24.90        1.218955               2.51       68.830
# 401               27.38        1.094751               7.95      185.380
# 57                12.14        5.415651               4.76       42.700
# 227               19.85        0.000000                3.1       93.495
# 244             -119.89        0.000000               0.54      153.150
# 199                5.89        6.784387                1.9       13.480
# 181               25.26        1.352004               2.36       67.540
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 453         57.20  2.695753e+10  2.521000e+09         0.937310
# 425         26.01  2.889375e+10  0.000000e+00         2.109662
# 192         27.93  1.370608e+10 -5.067000e+09         1.299448
# 333         50.35  1.067761e+11  5.162000e+09         3.054993
# 401        124.64  4.658595e+10  3.021000e+09        10.254704
# 57          32.55  2.267133e+11  4.965300e+10         1.408315
# 227         65.28  1.145296e+10  1.033985e+09         1.262194
# 244         84.21  1.822096e+10 -8.168600e+07        17.026990
# 199         10.19  4.241433e+10  9.281000e+09         0.270541
# 181         51.96  1.104068e+10  7.216430e+08         2.190319
#
#      price_per_book                                        sec_filings
# 453            2.55  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 425            1.97  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 192            2.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 333            8.91  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 401           50.56  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 57             1.80  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 227            3.74  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 244           10.25  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 199            1.26  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 181            5.55  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify the number of records in the DataFrame, and compare it with the number of rows in the original file.

# %%
df.count()
# Out:
# symbol                504
# name                  502
# sector                501
# price                 500
# price_per_earnings    497
# dividend_yield        499
# earnings_per_share    498
# 52_week_low           500
# 52_week_high          500
# market_cap            500
# ebitda                492
# price_per_sales       500
# price_per_book        492
# sec_filings           500
# dtype: int64

# %% [markdown]
# ### Identify nulls records

# %%
df.isnull().mean()
df.isnull().sum()
# Out:
# symbol                 0
# name                   2
# sector                 3
# price                  4
# price_per_earnings     7
# dividend_yield         5
# earnings_per_share     6
# 52_week_low            4
# 52_week_high           4
# market_cap             4
# ebitda                12
# price_per_sales        4
# price_per_book        12
# sec_filings            4
# dtype: int64

# %% [markdown]
# ### Drop Null Records

# %% [markdown]
# ### Validate nulls have been dropped

# %% [markdown]
# ### Default null `ebitda` values to 0. Then, validate no records are null for ebitda.

# %%
df['ebitda'] = df['ebitda'].fillna(0)
df['ebitda'].isnull().mean()
df.loc[:, ['ebitda']]
# Out:
#            ebitda
# 0    9.048000e+09
# 1    0.000000e+00
# 2    5.744000e+09
# 3    1.031000e+10
# 4    2.704000e+09
# ..            ...
# 499  7.220000e+08
# 500  2.289000e+09
# 501  2.007400e+09
# 502  0.000000e+00
# 503  1.734000e+09
#
# [504 rows x 1 columns]

# %% [markdown]
# ### Drop Duplicates

# %%
df.duplicated()
df.drop_duplicates()
# Out:
#     symbol                    name                  sector    price  \
# 0      MMM              3M Company             Industrials  $222.89
# 1      AOS         A.O. Smith Corp             Industrials      NaN
# 2      ABT     Abbott Laboratories             Health Care    56.27
# 3     ABBV             AbbVie Inc.             Health Care   108.48
# 4     ATVI     Activision Blizzard  Information Technology    65.83
# ..     ...                     ...                     ...      ...
# 499    XYL              Xylem Inc.             Industrials    70.24
# 500    YUM         Yum! Brands Inc  Consumer Discretionary     76.3
# 501    ZBH  Zimmer Biomet Holdings             Health Care   115.53
# 502   ZION           Zions Bancorp              Financials    50.71
# 503    ZTS                  Zoetis             Health Care    71.51
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0                 24.31        2.332862              $7.92      259.770
# 1                   NaN             NaN                NaN          NaN
# 2                 22.51        1.908982               0.26       64.600
# 3                 19.41        2.499560               3.29      125.860
# 4                   NaN        0.431903               1.28       74.945
# ..                  ...             ...                ...          ...
# 499               30.94        1.170079               1.83       76.810
# 500               27.25        1.797080               4.07       86.930
# 501               14.32        0.794834               9.01      133.490
# 502               17.73        1.480933                2.6       55.610
# 503               32.80        0.682372               1.65       80.130
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 0          175.49  1.387211e+11  9.048000e+09         4.390271
# 1             NaN           NaN  0.000000e+00              NaN
# 2           42.28  1.021210e+11  5.744000e+09         3.740480
# 3           60.05  1.813863e+11  1.031000e+10         6.291571
# 4           38.93  5.251867e+10  2.704000e+09        10.595120
# ..            ...           ...           ...              ...
# 499         46.86  1.291502e+10  7.220000e+08         2.726209
# 500         62.85  2.700330e+10  2.289000e+09         6.313636
# 501        108.17  2.445470e+10  2.007400e+09         3.164895
# 502         38.43  1.067068e+10  0.000000e+00         3.794579
# 503         52.00  3.599111e+10  1.734000e+09         9.280896
#
#      price_per_book                                        sec_filings
# 0             11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1               NaN                                                NaN
# 2              3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3             26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4              5.16  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..              ...                                                ...
# 499            5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500          212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501            2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502            1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503           18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [504 rows x 14 columns]

# %% [markdown]
# ### Sample `price` field

# %%
df['price'].sample(10)
# Out:
# 56      85.16
# 328     36.61
# 108    189.27
# 378    180.49
# 101      48.9
# 238      15.1
# 118    $43.10
# 24      37.14
# 498     41.26
# 454     52.65
# Name: price, dtype: object

# %% [markdown]
# ### Clean `price` Series by replacing `$`

# %%
df['price'] = df['price'].str.replace('$', ' ')
df['price'].sample(10)
# Out:
# 303     54.73
# 56      85.16
# 79      62.69
# 82      90.47
# 475     32.71
# 283     38.86
# 385     12.82
# 472     92.28
# 265     65.98
# 96     100.36
# Name: price, dtype: object

# %% [markdown]
# ### Confirm data type of `price`

# %%
df.dtypes
# Out:
# symbol                 object
# name                   object
# sector                 object
# price                  object
# price_per_earnings    float64
# dividend_yield        float64
# earnings_per_share     object
# 52_week_low           float64
# 52_week_high          float64
# market_cap            float64
# ebitda                float64
# price_per_sales       float64
# price_per_book        float64
# sec_filings            object
# dtype: object

# %% [markdown]
# ### Cast `price` Series as float and then validate using `dtype`

# %%
df['price'] = df['price'].astype('float')
df.dtypes
# Out:
# symbol                 object
# name                   object
# sector                 object
# price                 float64
# price_per_earnings    float64
# dividend_yield        float64
# earnings_per_share     object
# 52_week_low           float64
# 52_week_high          float64
# market_cap            float64
# ebitda                float64
# price_per_sales       float64
# price_per_book        float64
# sec_filings            object
# dtype: object
